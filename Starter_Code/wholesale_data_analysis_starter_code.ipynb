# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
src_data_path = r'Resources/client_dataset.csv'
df = pd.read_csv(src_data_path)
df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe
# Out:
# <bound method NDFrame.describe of            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
# ...

# %% [markdown]
# #### Use this space to do any additional research and familiarize yourself with the data.

# %% [markdown]
# - Overall Info About the Client and their Purchase habits

# %%
client_info = df[['client_id','first', 'last', 'phone', 'email', 
                          'job', 'order_id', 'order_date', 'order_week',  'item_id', 'category', 'subcategory', 'unit_price', 
                          'unit_cost', 'unit_weight', 'qty', 'line_number']]
client_info
# Out:
#        client_id      first       last               phone  \
# 0          58515     Donald    Harding  793-904-7725x39308
# 1          37609    Tiffany      Myers    201.442.4543x942
# 2          57113    Shannon     Watson   687.737.9424x8503
# 3          46554     Nathan      Baker    827-788-8123x012
# 4          92089  Christina   Schwartz        265-829-3643
# ...          ...        ...        ...                 ...
# 54634      29043     Lauren      Reese  977.877.5272x11382
# 54635      41908    Derrick      Moore        358.661.5483
# 54636      35176     Monica  Gutierrez    294.805.9100x339
# 54637      24485      Wanda    Solomon       (311)767-4924
# 54638      24007     Dwayne       Bell   606-619-7667x9508
#
#                                      email                      job  order_id  \
# 0         harding.donald.7185@sullivan.com             Immunologist   8953482
# 1        myers.t.6537@ferguson-johnson.net          Music therapist   8069089
# ...

# %% [markdown]
# - Client Personal Identifiable Info

# %%
client_pii = df[['client_id','first', 'last', 'phone', 'email', 'job']]
client_pii
# Out:
#        client_id      first       last               phone  \
# 0          58515     Donald    Harding  793-904-7725x39308
# 1          37609    Tiffany      Myers    201.442.4543x942
# 2          57113    Shannon     Watson   687.737.9424x8503
# 3          46554     Nathan      Baker    827-788-8123x012
# 4          92089  Christina   Schwartz        265-829-3643
# ...          ...        ...        ...                 ...
# 54634      29043     Lauren      Reese  977.877.5272x11382
# 54635      41908    Derrick      Moore        358.661.5483
# 54636      35176     Monica  Gutierrez    294.805.9100x339
# 54637      24485      Wanda    Solomon       (311)767-4924
# 54638      24007     Dwayne       Bell   606-619-7667x9508
#
#                                      email                      job
# 0         harding.donald.7185@sullivan.com             Immunologist
# 1        myers.t.6537@ferguson-johnson.net          Music therapist
# ...

# %% [markdown]
# - Client Order Info

# %%
order_info = df[['order_id', 'order_date', 'order_week','unit_price', 
                          'unit_cost', 'unit_weight', 'qty']]
order_info
# Out:
#        order_id  order_date  order_week  unit_price  unit_cost  unit_weight  \
# 0       8953482  2023-04-28          17     1096.80     762.71         7.50
# 1       8069089  2023-05-19          20       24.95      15.09         1.49
# 2       1902144  2023-01-29           4       13.52       7.86         1.68
# 3       9031802  2023-04-25          17       36.42      24.85         1.23
# 4       1322274  2023-05-28          21      195.10     108.17        46.43
# ...         ...         ...         ...         ...        ...          ...
# 54634   9021716  2023-04-26          17       83.13      51.60         2.25
# 54635   6290153  2023-02-08           6      206.59     175.46        11.70
# 54636   8692622  2023-03-05           9       65.66      57.31         4.16
# 54637   7592730  2023-01-18           3        1.48       1.22        18.04
# 54638   7489403  2023-01-04           1        3.01       1.61         2.07
#
#         qty
# 0       105
# 1        21
# 2        39
# ...

# %% [markdown]
# - Product Information

# %%
item_info = df[['line_number', 'item_id', 'category', 'subcategory']]
item_info
# Out:
#        line_number         item_id     category         subcategory
# 0                1  EUD29711-63-6U        decor            wall art
# 1                0  XDA18116-89-4A  consumables                pens
# 2                6  ABE59463-05-7E     software  project management
# 3                3  ZMM00836-65-0C  consumables                pens
# 4                1  BZX55559-12-3X  consumables                misc
# ...            ...             ...          ...                 ...
# 54634            8  UCA28532-31-0B     software           logistics
# 54635            0  EBD29277-23-7U  consumables    kitchen supplies
# 54636            6  EBD30093-55-9Z  consumables   bathroom supplies
# 54637            0  XMZ38239-49-3D    furniture              stands
# 54638            5  ZCZ05589-50-5D     software  project management
#
# [54639 rows x 4 columns]

# %%
# What three item categories had the most entries?
most_cat_entries = item_info['category'].value_counts().head(3)
most_cat_entries
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries, which subcategory had the most entries?

# most_sub_cat_entries = pd.concat(most_cat_entries, item_info['subcategory'])
most_subcat_entries = item_info['subcategory'].value_counts().head(1)
most_subcat_entries
# Out:
# subcategory
# bathroom supplies    6424
# Name: count, dtype: int64

# %%
# Which five clients had the most entries in the data?
most_five_client_entries = client_pii['client_id'].value_counts().head(5)
most_five_client_entries
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
list_top_fiveclients = list(most_five_client_entries.index)
list_top_fiveclients
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the client with the most entries order order?
clientID_Max = client_pii['client_id'].value_counts().idxmax()
clientID_Max
clientID = df[client_pii['client_id'] == clientID_Max]
total_qty = clientID['qty'].sum()
print(f'Client ID {clientID_Max} ordered the most items which sums up to {total_qty} quantities')
# Out:
# Client ID 33615 ordered the most items which sums up to 64313 quantities

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty
df1 = df.copy()
df1['subtotal'] = (order_info['unit_price'] * order_info['qty'])
df1
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.
def assign_shipping_prices(item_weight):
    match item_weight:
        case num if num > 50:
            item_weight = item_weight * 7
        case num if num <= 50:
            item_weight = item_weight * 10
    return item_weight
df1['shipping_price'] = order_info['unit_weight'].apply(assign_shipping_prices)
df1
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%
tax_rate = 9.25 / 100
print(tax_rate)
df1['total_price'] = (df1['subtotal'] + df1['shipping_price']) * (1 + tax_rate)
df1
# Out:
# 0.0925
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the cost of each line using unit cost, qty, and
# shipping price (assume the shipping cost is exactly what is charged to the client).
df1['item_cost'] = (order_info['unit_cost'] * order_info['qty']) + df1['shipping_price']
df1
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the profit of each line using line cost and line price
df1['profit'] = df1['total_price'] - df1['item_cost']
df1['profit'] = df1['profit']


df1
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
target_order = {
    'order_id': [2742071, 2173913, 6128929],
    'reciept_total_price': [15281189, 16238871, 92344125]

}
consolidate_orders = df1.groupby('order_id')['total_price'].sum().reset_index()
consolidate_orders.rename(columns={'total_price' : 'Total Price'}, inplace=True)
target_order_data = pd.DataFrame(target_order)
comparison = pd.merge(consolidate_orders, target_order_data, on='order_id')
comparison['Match'] = abs(comparison['Total Price'] - comparison['reciept_total_price']) < 1e-2
comparison
# Out:
#    order_id  Total Price  reciept_total_price  Match
# 0   2173913    119838.36             16238871  False
# 1   2742071    139844.51             15281189  False
# 2   6128929    752748.75             92344125  False

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity spend? Check your work from Part 1 for client ids.
amt_spent = []
for client in list_top_fiveclients:
    client_data = df1.loc[df1['client_id'] == client]
    total_spent_qty = client_data['qty'].sum()
    total_spent = client_data['total_price'].sum()
    amt_spent.append({'client_id': client, 'qty_spent': total_spent_qty, 'total_spent': round(total_spent, 2)})
total_qty_spent = pd.DataFrame(amt_spent)
print(total_qty_spent)
# Out:
#    client_id  qty_spent  total_spent
# 0      33615      64313   6392918.35
# 1      66037      43018   8746255.31
# 2      46820      75768   8006332.53
# 3      38378      73667   9172866.14
# 4      24741     239862  76678479.05

# %%
# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit.
pd.set_option('display.float_format', lambda x: '%.2f' % x)
client_summary = df1.groupby('client_id').agg({
    'qty' : 'sum',
    'shipping_price': 'sum',
    'subtotal': 'sum',
    'profit': 'sum'
}).reset_index()
client_summary = client_summary.round(2)
top_client_summary = client_summary.sort_values(by='subtotal', ascending=False).head(5)
top_client_summary
# Out:
#      client_id      qty  shipping_price     subtotal       profit
# 758      78965  4033302         7383.30 595047041.80 246859505.41
# 840      85931   644423         2763.00 207192783.92 108358048.60
# 320      38473   402770         7832.20 163620503.65  42946283.31
# 850      86721  1010426         6154.60 101583079.67  37024209.98
# 821      84344   466968         6944.00  92871825.66  27273283.52

# %%
# Format the data and rename the columns to names suitable for presentation.

# Define the money columns. 
df1

# Define a function that converts a dollar amount to millions.
def currency_format_millions(amt):
    return amt/1_000_000

# # Apply the currency_format_millions function to only the money columns. 
overall_report_data = df1[['subtotal','shipping_price','total_price','item_cost','profit']].apply(currency_format_millions)
overall_report_data.rename(columns={
'subtotal' : 'Subtotal (millions)',
'shipping_price' : 'Shipping Price (millions)',
'total_price' : 'Total Price (millions)',
'item_cost' : 'Item Cost (millions)',
'profit' : 'Profit (millions)'
}, inplace=True)
overall_report_data
# Rename the columns to reflect the change in the money format.
# Out:
#        Subtotal (millions)  Shipping Price (millions)  Total Price (millions)  \
# 0                     0.12                       0.00                    0.13
# 1                     0.00                       0.00                    0.00
# 2                     0.00                       0.00                    0.00
# 3                     0.00                       0.00                    0.00
# 4                     0.00                       0.00                    0.00
# ...                    ...                        ...                     ...
# 54634                 0.00                       0.00                    0.00
# 54635                 0.01                       0.00                    0.01
# 54636                 0.03                       0.00                    0.03
# 54637                 0.00                       0.00                    0.00
# 54638                 0.00                       0.00                    0.00
#
# ...

# %%
# Sort the updated data by "Total Profit (millions)" form highest to lowest and assign the sort to a new DatFrame.
overall_report_data.sort_values(by='Total Price (millions)', ascending=False).round(2)
# Out:
#        Subtotal (millions)  Shipping Price (millions)  Total Price (millions)  \
# 21801               584.47                       0.00                  638.54
# 15112               206.12                       0.00                  225.19
# 23929               148.25                       0.00                  161.96
# 25972                98.10                       0.00                  107.18
# 11740                82.45                       0.00                   90.08
# ...                    ...                        ...                     ...
# 22529                 0.00                       0.00                    0.00
# 37936                 0.00                       0.00                    0.00
# 29972                 0.00                       0.00                    0.00
# 21090                 0.00                       0.00                    0.00
# 38399                 0.00                       0.00                    0.00
#
# ...

# %% [markdown]
# # Insight
# ##### Leadership was currious to get an insight as to based on the analyzed data which clients should be our target demographics within a certain profession
# - Based on the current operating model and the our attractive price point, it seems to appear that customer with the following job titles Chief of Staff, Dietitian Osteopath, Pension scheme manager, and Production designer, theatre/television/film are our top customers.
# - Given this information, economically, it makese sense to invest, market and cross sell other products and services we offer to these target demographics

# %%
# round(df1.groupby('job')['qty'].sum().reset_index(), 2).sort_values
pd.set_option('display.float_format', lambda x: '%.2f' % x)
insight_data = pd.merge(df1, total_qty_spent, on='client_id')
insight_data = insight_data.groupby('job')['total_spent'].sum().reset_index()
insight_data
# Out:
#                                             job    total_spent
# 0                                Chief of Staff  1673323498.77
# 1                                     Dietitian  1898783290.98
# 2                                     Osteopath  1845459870.41
# 3                        Pension scheme manager 15872445163.35
# 4  Production designer, theatre/television/film  1406442037.00
